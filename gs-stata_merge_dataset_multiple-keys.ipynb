# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel('C:/Users/Arshad/Downloads/GS-stata.xlsx')

# %%
df
# Out:
#             Country Name                                        Series Name  \
# 0              Australia  General government final consumption expenditu...
# 1                  China  General government final consumption expenditu...
# 2                  India  General government final consumption expenditu...
# 3                  Japan  General government final consumption expenditu...
# 4            Korea, Rep.  General government final consumption expenditu...
# 5                 Mexico  General government final consumption expenditu...
# 6            Switzerland  General government final consumption expenditu...
# 7                 Turkey  General government final consumption expenditu...
# 8         United Kingdom  General government final consumption expenditu...
# 9          United States  General government final consumption expenditu...
# 10                Angola  General government final consumption expenditu...
# ...

# %%
df2=df.drop(['Unnamed: 2','Unnamed: 3','Unnamed: 4'], axis=1, inplace=True)

# %%
df.set_index('Country Name')
# Out:
#                                                             Series Name  \
# Country Name
# Australia             General government final consumption expenditu...
# China                 General government final consumption expenditu...
# India                 General government final consumption expenditu...
# Japan                 General government final consumption expenditu...
# Korea, Rep.           General government final consumption expenditu...
# Mexico                General government final consumption expenditu...
# Switzerland           General government final consumption expenditu...
# Turkey                General government final consumption expenditu...
# United Kingdom        General government final consumption expenditu...
# United States         General government final consumption expenditu...
# Angola                General government final consumption expenditu...
# Botswana              General government final consumption expenditu...
# ...

# %%
df2 = pd.melt(df, id_vars=['Country Name','Series Name'],var_name='Year', value_name='value')
df2
# Out:
#              Country Name                                        Series Name  \
# 0               Australia  General government final consumption expenditu...
# 1                   China  General government final consumption expenditu...
# 2                   India  General government final consumption expenditu...
# 3                   Japan  General government final consumption expenditu...
# 4             Korea, Rep.  General government final consumption expenditu...
# ..                    ...                                                ...
# 763              Tanzania  General government final consumption expenditu...
# 764                  Togo  General government final consumption expenditu...
# 765                Uganda  General government final consumption expenditu...
# 766  United Arab Emirates  General government final consumption expenditu...
# 767                Zambia  General government final consumption expenditu...
#
#      Year      value
# 0    2000  17.787098
# ...

# %%
df3=pd.read_excel('C:/Users/Arshad/Documents/Salu/merge/data-stata-final.xlsx')
df3
# Out:
#      CountryName  Year   INFLATION       TOPEN  LogGDPPerCapita  MoneyGrowth  \
# 0              1  2000  325.000000  152.547110       556.836318   303.735499
# 1              1  2001  152.600000  150.335795       527.333529   163.003104
# 2              1  2002  108.900000  105.301743       872.494492   156.340680
# 3              1  2003   98.224144  103.901227       982.960899    68.098314
# 4              1  2004   43.542107  103.579924      1255.564045    48.551965
# ..           ...   ...         ...         ...              ...          ...
# 763           49  2011    6.429397   76.212834      1672.949830    21.701980
# 764           49  2012    6.575900   79.099742      1763.094184    17.859427
# 765           49  2013    6.977676   84.597289      1878.903489    20.791580
# 766           49  2014    7.806876   80.063561      1763.056239    12.618085
# 767           49  2015   10.110593   79.865155      1337.796315    35.192471
#
# ...

# %%
df2.to_csv (r'C:/Users/Arshad/Documents/Salu/merge/gs-stata.csv')
df2
# Out:
#              Country Name                                        Series Name  \
# 0               Australia  General government final consumption expenditu...
# 1                   China  General government final consumption expenditu...
# 2                   India  General government final consumption expenditu...
# 3                   Japan  General government final consumption expenditu...
# 4             Korea, Rep.  General government final consumption expenditu...
# ..                    ...                                                ...
# 763              Tanzania  General government final consumption expenditu...
# 764                  Togo  General government final consumption expenditu...
# 765                Uganda  General government final consumption expenditu...
# 766  United Arab Emirates  General government final consumption expenditu...
# 767                Zambia  General government final consumption expenditu...
#
#      Year      value
# 0    2000  17.787098
# ...

# %%
df2.drop(['Series Name'], axis=1, inplace=True)

# %%
df2.rename({'value': 'General government final consumption expenditure'},axis=1, inplace=True )

# %%
df3.rename({'Country Name': 'CountryName','CountryName_new': 'Country Name', },axis=1, inplace=True )

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CountryName      768 non-null    int64
#  1   Year             768 non-null    int64
#  2   INFLATION        768 non-null    float64
#  3   TOPEN            768 non-null    float64
#  4   LogGDPPerCapita  768 non-null    float64
#  5   MoneyGrowth      768 non-null    float64
#  6   Fuelexports      768 non-null    object
#  7   Termoftrade      768 non-null    float64
#  8   Exchangerate     768 non-null    float64
#  9   DebttoGDPratio   768 non-null    float64
#  10  Fuelexports_new  767 non-null    float64
#  11  Country Name     768 non-null    object
# dtypes: float64(8), int64(2), object(2)
# memory usage: 72.1+ KB

# %%
df2.Year=list(map(int, df2.Year))
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 3 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Country Name                                      768 non-null    object
#  1   Year                                              768 non-null    int64
#  2   General government final consumption expenditure  768 non-null    float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 18.1+ KB

# %%
df4=pd.merge(df2, df3, on=['Country Name', 'Year'])

# %%
df4.head(10)
# Out:
#      Country Name  Year  General government final consumption expenditure  \
# 0       Australia  2000                                         17.787098
# 1           China  2000                                         16.633346
# 2           India  2000                                         11.947835
# 3           Japan  2000                                         16.852039
# 4     Korea, Rep.  2000                                         11.338342
# 5          Mexico  2000                                          9.515219
# 6     Switzerland  2000                                         11.577088
# 7          Turkey  2000                                         11.986495
# 8  United Kingdom  2000                                         16.780617
# 9   United States  2000                                         14.026010
#
#    CountryName  INFLATION      TOPEN  LogGDPPerCapita  MoneyGrowth  \
# 0            2   4.457435  41.029011     21679.247840     3.739910
# ...

# %%
df4.to_csv (r'C:/Users/Arshad/Documents/Salu/merge/gs-stata_merged.csv')
